# %%
import pandas as pd

df = pd.read_csv('/Users/festusedward-n/Downloads/Final Analysis_for_user_perspectives.csv')

# %%
df.head()
# Out:
#                      Timestamp         What is your Name  \
# 0  2024/11/27 2:44:58 PM GMT+9   Why do you need my name
# 1  2024/12/06 5:09:35 PM GMT+9  Harun Humphrey Kabalika
# 2  2024/12/06 6:17:28 PM GMT+9                       NaN
# 3  2024/12/06 7:23:11 PM GMT+9    OMARI ATHUMANI MZIRAY
# 4  2024/12/06 7:28:32 PM GMT+9          Viana Mbonimpaye
#
#                                                Email Age group  Gender  \
# 0  why do you need my email-i will not feel safe ...     35–44  Female
# 1                           harunkabalika@gmail.com      25–34    Male
# 2                                plukuliko@gmail.com     25–34    Male
# 3                           omarimziray865@gmail.com     25–34    Male
# 4                            vianamulokozi@yahoo.com     25–34  Female
#
#   Which devices do you typically use to access your Internet Banking account? (Select all that apply)  \
# 0                                         Smartphone
# ...

# %%
df.shape
# Out:
# (101, 27)
