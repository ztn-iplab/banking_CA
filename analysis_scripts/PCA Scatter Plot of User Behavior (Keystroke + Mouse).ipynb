# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Fill missing values and standardize
X = numeric_cols.fillna(0)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(X_scaled)

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(pca_components[:, 0], pca_components[:, 1], alpha=0.7)
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.title("PCA Scatter Plot of User Behavior (Keystroke + Mouse)")
plt.grid(True)
plt.tight_layout()
plt.savefig("pca_user_behavior.pdf")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.histplot(keystroke_df['session_duration_sec'], bins=30, kde=True)
plt.title("Distribution of Keystroke Session Duration (seconds)")
plt.xlabel("Session Duration (sec)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.savefig("keystroke_session_duration_distribution.pdf")
plt.show()

# %%
import pandas as pd

# Load the user-level mouse features CSV
mouse_user_df = pd.read_csv("mouse_user_features.csv")

# Confirm the columns
print(mouse_user_df.columns)
# Out:
# Index(['user_id', 'distance_mean_mean', 'distance_mean_std',
#        'distance_sum_total', 'speed_mean_mean', 'speed_mean_std',
#        'speed_max_max', 'click_count_total', 'click_count_mean',
#        'action_count_total', 'session_duration_sum', 'session_duration_mean',
#        'session_duration_std'],
#       dtype='object')

# %%
print(mouse_user_df.columns.tolist())
# Out:
# ['user_id', 'distance_mean_mean', 'distance_mean_std', 'distance_sum_total', 'speed_mean_mean', 'speed_mean_std', 'speed_max_max', 'click_count_total', 'click_count_mean', 'action_count_total', 'session_duration_sum', 'session_duration_mean', 'session_duration_std']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(data=mouse_user_df, x='distance_sum_total', y='speed_mean_mean')
plt.title("Mouse Total Distance vs. Average Speed per User")
plt.xlabel("Total Distance (sum)")
plt.ylabel("Average Speed (mean)")
plt.tight_layout()
plt.savefig("mouse_total_distance_vs_avg_speed.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=mouse_user_df.sort_values('click_count_total', ascending=False), x='user_id', y='click_count_total')
plt.title("Total Mouse Clicks per User")
plt.xticks(rotation=90)
plt.xlabel("User ID")
plt.ylabel("Total Clicks")
plt.tight_layout()
plt.savefig("mouse_clicks_per_user.pdf")
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(combined_df.corr(), cmap='coolwarm', annot=True, fmt=".2f")
plt.title("Feature Correlation Matrix")
plt.tight_layout()
plt.savefig("behavioral_feature_correlation_heatmap.pdf")
plt.show()
